# %%
from MFDFA import IMFs
import matplotlib.pyplot as plt
import mne
import numpy as np

raw1 = mne.io.read_raw_edf(r'Archivos\Subject00\edf\Subject00_1.edf')
raw2 = mne.io.read_raw_edf(r'Archivos\Subject00\edf\Subject00_2.edf')

raw = mne.concatenate_raws([raw1, raw2])

IMF = IMFs(data:=raw.get_data()[0])
IMF
# Out:
# Extracting EDF parameters from c:\Users\JuanD\Documents\vscode\semillero\Archivos\Subject00\edf\Subject00_1.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from c:\Users\JuanD\Documents\vscode\semillero\Archivos\Subject00\edf\Subject00_2.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# array([[ 6.28562842e-07, -6.43077488e-08, -7.80628744e-07, ...,
#         -5.29088675e-06, -5.27237974e-06, -5.25371086e-06],
#        [-4.27650047e-06, -4.17217393e-06, -4.17358958e-06, ...,
#          5.29047314e-06,  5.27196614e-06,  5.25329725e-06]])

# %%
plt.plot(data, color='black')
plt.plot(np.sum(IMF[[0], :], axis=0).T, color='b')

# %%
plt.plot(data, color='black')
plt.plot(np.sum(IMF[[1], :], axis=0).T, color='b')
